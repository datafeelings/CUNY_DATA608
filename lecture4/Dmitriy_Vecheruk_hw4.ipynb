# %% [markdown]
# ## CUNY MSDA Fall 2017 Semester
# ### DATA 620
#
# **Homework 4: Hudson River Enterococcus Levels Analysis**
#
# By Dmitriy Vecheruk

# %% [markdown]
# This analysis is based on the initial [example provided in the course](https://github.com/charleyferrari/CUNY_DATA608/blob/master/lecture4/Hudson_River.ipynb).
#
# Data source: Riverkeeper (www.riverkeeper.org) data on Hudson River Enterococcus levels

# %% [markdown]
# ### 1. Load libraries and preprocess the data

# %%
import pandas as pd
import numpy as np
import plotly.offline as py
from plotly.graph_objs import *
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
dat = pd.read_csv("https://raw.githubusercontent.com/datafeelings/CUNY_DATA608/master/lecture4/Data/riverkeeper_data_2013.csv")

# %% [markdown]
# Let's look at the data:

# %%
dat[0:8]
# Out:
#                         Site        Date EnteroCount  FourDayRainTotal  \
# 0  Hudson above Mohawk River  10/16/2011        1733               1.5
# 1  Hudson above Mohawk River  10/21/2013           4               0.2
# 2  Hudson above Mohawk River   9/21/2013          20               0.0
# 3  Hudson above Mohawk River   8/19/2013           6               0.0
# 4  Hudson above Mohawk River   7/21/2013          31               0.0
# 5  Hudson above Mohawk River    6/4/2013         238               1.2
# 6  Hudson above Mohawk River  10/15/2012          23               1.4
# 7  Hudson above Mohawk River   9/15/2012          11               0.1
#
#    SampleCount
# 0           35
# 1           35
# 2           35
# 3           35
# 4           35
# 5           35
# 6           35
# 7           35

# %%
dat.dtypes
# Out:
# Site                        object
# Date                datetime64[ns]
# EnteroCount                 object
# FourDayRainTotal           float64
# SampleCount                  int64
# dtype: object

# %% [markdown]
# Python is not recognizing `Date` and `EnteroCount` as numeric fields! Let's fix that

# %%
dat["Date"] = pd.to_datetime(dat["Date"],format="%m/%d/%Y")

# %%
# check if any dates could not be parsed 
dat[dat.Date.isnull()]
# Out:
# Empty DataFrame
# Columns: [Site, Date, EnteroCount, FourDayRainTotal, SampleCount]
# Index: []

# %%
print min(dat["Date"]), max(dat["Date"])
# Out:
# 2006-09-19 00:00:00 2013-10-21 00:00:00

# %% [markdown]
# The dates seem to have been parsed correctly.
#
# As for the `EnteroCount`, the probem was the "<" and ">" signs present in the field to highlight extreme values. We'll get rid of them. And to be more conservative, keep the border values instead.

# %%
dat[dat["EnteroCount"].str.contains("<|>",regex=True)]["EnteroCount"].unique()
# Out:
# array(['>2420', '<1', '<10', '>24196'], dtype=object)

# %%
dat["EnteroCount"] = dat["EnteroCount"].str.replace("<|>","") 
dat["EnteroCount"] = dat["EnteroCount"].astype("int")
dat.describe()
# Out:
#         EnteroCount  FourDayRainTotal  SampleCount
# count   3397.000000       3397.000000  3397.000000
# mean     387.747719          0.568001    56.886370
# std     2046.114024          1.000387    41.588476
# min        0.000000          0.000000    27.000000
# 25%       10.000000          0.000000    37.000000
# 50%       18.000000          0.200000    42.000000
# 75%       85.000000          0.700000    50.000000
# max    24196.000000          8.500000   187.000000

# %% [markdown]
# No NA values in the `EnteroCount` field, we can proceed to the analysis

# %% [markdown]
# ### 2. Analysis from the homework assignment
#
# 1) Create lists & graphs of the best and worst places to swim in the dataset.
# 2) The testing of water quality can be sporadic. Which sites have been tested most regularly? Which ones have long gaps between tests? Pick out 5-10 sites and visually compare how regularly their water quality is tested.
# 3) Is there a relationship between the amount of rain and water quality? Show this relationship graphically. If you can, estimate the effect of rain on quality at different sites and create a visualization to compare them.

# %% [markdown]
# #### 2.1. The best and worst places to swim in the dataset

# %%
len(dat.Site.unique())
# Out:
# 75

# %% [markdown]
# Overall, there are 75 unique measurement sites.
# First, inspect how the EnteroCount values are distributed over time and per site

# %%
plotly_data = [
    Scatter(
        x = dat['Date'],
        y = dat['EnteroCount'],
        mode = 'markers'
    )
]

layout = Layout(title="Observed Entero levels over time",
                xaxis=dict(title='Measurement time'),
                yaxis=dict(title='Enterococcus count per 100mL'))

fig = Figure(data=plotly_data, layout=layout)
py.iplot(fig)
# Out:
# <div id="a9b3c95a-397b-48aa-a214-add1be0a431f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a9b3c95a-397b-48aa-a214-add1be0a431f", [{"y": [1733, 4, 20, 6, 31, 238, 23, 11, 15, 6, 10, 11, 30, 11, 231, 11, 11, 91, 2420, 15, 25, 31, 12, 1, 4, 28, 276, 2420, 6, 1, 6, 41, 15, 12, 23, 479, 2420, 27, 50, 130, 830, 1733, 64, 1300, 461, 770, 1300, 461, 21, 1023, 238, 2420, 68, 142, 33, 4, 96, 128, 12, 26, 117, 42, 32, 416, 1986, 2420, 48, 12, 8, 2420, 22, 727, 45, 17, 42, 11, 4, 54, 272, 2420, 260, 99, 41, 30, 117, 199, 387, 579, 67, 345, 32, 1986, 96, 63, 108, 34, 72, 1553, 96, 49, 28, 33, 64, 65, 67, 980, 1203, 40, 24, 56, 30, 1300, 56, 61, 7, 6, 20, 18, 24, 1414, 50, 36, 435, 219, 17, 81, 525, 31, 727, 84, 50, 602, 28, 96, 190, 2420, 46, 35, 7, 47, 26, 38, 33, 108, 411, 139, 143, 45, 201, 3, 88, 42, 2420, 161, 39, 25, 7, 12, 21, 82, 921, 687, 31, 82, 687, 59, 2420, 40, 53, 18, 12, 21, 81, 1300, 75, 36, 40, 30, 51, 20, 22, 17, 32, 20, 134, 46, 29, 19, 1553, 1553, 411, 211, 17, 179, 3, 187, 2420, 687, 34, 76, 84, 770, 488, 88, 488, 59, 25, 6, 135, 980, 49, 43, 76, 2420, 32, 84, 88, 10, 50, 16, 33, 19, 32, 40, 1046, 146, 13, 22, 11, 29, 2420, 93, 866, 30, 1733, 2420, 104, 20, 122, 137, 613, 12, 23, 163, 2420, 727, 179, 2, 1414, 100, 6, 39, 18, 46, 2420, 32, 26, 43, 8, 68, 85, 1120, 57, 20, 20, 13, 4, 1, 5, 18, 14, 9, 921, 727, 16, 4, 13, 11, 2420, 21, 91, 17, 6, 7, 20, 24, 52, 4, 7, 17, 1414, 20, 1, 4, 5, 291, 126, 770, 687, 21, 26, 1, 64, 7, 8, 26, 649, 328, 25, 2, 9, 22, 25, 5, 14, 20, 69, 1733, 31, 8, 5, 6, 38, 45, 5, 1986, 1, 3, 11, 194, 8, 14, 1, 649, 22, 8, 10, 16, 8, 5, 15, 6, 12, 63, 1986, 11, 6, 6, 34, 
, 20, 21, 8, 1, 11, 2, 15, 38, 23, 2, 35, 166, 4, 70, 1, 4, 13, 31, 18, 3, 4, 2, 3, 219, 13, 7, 2, 20, 3, 219, 8, 3, 1, 4, 147, 64, 4, 9, 2, 3, 23, 99, 12, 1203, 1986, 4, 121, 152, 225, 17, 70, 44, 40, 42, 108, 34, 43, 33, 99, 2420, 49, 35, 1733, 86, 10 ...

# %% [markdown]
# We can see that while the values remain largely under the critical levels (EnteroCount of 2420 per 100ml), there are some spikes in the data. Also, there is a cap at 2420 due to our replacement of the ">2420" value.
# So a median value per site should be a good indicators of the overall water quality.
# We should however, also consider the changes in the quality over time, as the median does not reflect it.

# %%
dat_site_median = dat["EnteroCount"].groupby(dat["Site"]).agg(np.median).reset_index().sort_values("EnteroCount")

# %%
best_10 = dat_site_median.head(10)
worst_10 = dat_site_median.tail(10)

# %%
best_10.head(10)
# Out:
#                                   Site  EnteroCount
# 50            Norrie Point mid-channel          2.5
# 68                      Tivoli Landing          4.0
# 58     Port Ewen Drinking Water Intake          4.0
# 59  Poughkeepsie Drinking Water Intake          4.5
# 72              West Point STP Outfall          7.0
# 40                Kingston Point Beach          8.0
# 69                Ulster Landing Beach          8.5
# 71                    Wappingers Creek          9.0
# 44                    Marlboro Landing          9.0
# 37                     Irvington Beach         10.0

# %%
trace_best = Bar(x=best_10.EnteroCount,
                  y=best_10.Site,
                  name='Best 10',
                  marker=dict(color='green'),orientation = 'h')
    
trace_worst = Bar(x=worst_10.EnteroCount,
                  y=worst_10.Site,
                  name='Worst 10',
                  marker=dict(color='red'),orientation = 'h')

layout = Layout(title="10 Best and 10 Worst Sites by Water Quality",
                xaxis=dict(title='Enterococcus count per 100mL',type='log',autorange=True),
                yaxis=dict(title='Site name')
                )

fig = Figure(data=[trace_best,trace_worst], layout=layout)
py.iplot(fig)
# Out:
# <div id="7bf6c928-21ea-4fdb-8a48-3d5e33b8cf04" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7bf6c928-21ea-4fdb-8a48-3d5e33b8cf04", [{"orientation": "h", "marker": {"color": "green"}, "y": ["Norrie Point mid-channel", "Tivoli Landing", "Port Ewen Drinking Water Intake", "Poughkeepsie Drinking Water Intake", "West Point STP Outfall", "Kingston Point Beach", "Ulster Landing Beach", "Wappingers Creek", "Marlboro Landing", "Irvington Beach"], "x": [2.5, 4.0, 4.0, 4.5, 7.0, 8.0, 8.5, 9.0, 9.0, 10.0], "type": "bar", "name": "Best 10"}, {"orientation": "h", "marker": {"color": "red"}, "y": ["Kingston STP Outfall", "Hudson River above Troy Lock", "Dunn Memorial Bridge- Albany", "Saw Mill River", "Gowanus Canal", "Newtown Creek- Metropolitan Ave. Bridge", "Piermont Pier", "Newburgh Launch Ramp", "Mohawk River at Waterford", "Upper Sparkill Creek"], "x": [67.0, 67.0, 80.0, 86.0, 96.0, 98.0, 99.0, 120.0, 130.0, 411.0], "type": "bar", "name": "Worst 10"}], {"title": "10 Best and 10 Worst Sites by Water Quality", "xaxis": {"type": "log", "autorange": true, "title": "Enterococcus count per 100mL"}, "yaxis": {"title": "Site name"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
